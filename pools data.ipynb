# %% [markdown]
# # Pool Data Final Project

# %% [markdown]
# In order to find the best neighborhood, my group took the perspective of a kid. Because of this, I chose a dataset recording the pools and spray parks in Pittsburgh neighborhoods and their locations. The best neighborhoods are the ones pools and/or sprayparks. These features add to the childhood funness of the area and are what make life worth living!

# %%
import pandas as pd
pool_data = pd.read_csv('https://data.wprdc.org/datastore/dump/5cc254fe-2cbd-4912-9f44-2f95f0beea9a')

# %%
df = pool_data['neighborhood'].value_counts()
print(df)
# Out:
# neighborhood
# South Side Flats            2
# Highland Park               2
# Bedford Dwellings           1
# South Side Slopes           1
# Westwood                    1
# Polish Hill                 1
# Beltzhoover                 1
# Allegheny Center            1
# Sheraden                    1
# Squirrel Hill South         1
# Perry North                 1
# Mount Washington            1
# Carrick                     1
# Brookline                   1
# Banksville                  1
# Shadyside                   1
# Lincoln Place               1
# Greenfield                  1
# Brighton Heights            1
# Homewood South              1
# East Hills                  1
# Troy Hill                   1
# Hazelwood                   1
# Bloomfield                  1
# Beechview                   1
# Lincoln-Lemington-Belmar    1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.plot.bar(color = {"slateblue"})
plt.title ("Number of Pools per Neighborhood in Pittsburgh")
plt.show()

# %% [markdown]
# In conclusion, South Side Flats and Highland Park and the very best Pittsburgh neighborhoods due to the abundance of pools and/or spray parks (2 total).The remaining neighborhoods are tied for second place with 1 pool. Any unlisted neighborhood should be completey blacklisted, as they have no pools or sprayparks and they hate fun and hate children.
